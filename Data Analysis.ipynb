# %% [markdown]
# # Data analysis project

# %% [markdown]
# ### In this project we will focus on EDA (Exploratory data analysis) of stock prices.we will focus on the bank stocks and see how they are progressed throught the financial crisis all the way to early 2016.

# %%
#pandas-datareader
#pip install pandas_datareader
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Requirement already satisfied: pandas>=0.23 in g:\python_1\lib\site-packages (from pandas_datareader) (1.2.4)
# Requirement already satisfied: lxml in g:\python_1\lib\site-packages (from pandas_datareader) (4.6.3)
# Requirement already satisfied: requests>=2.19.0 in g:\python_1\lib\site-packages (from pandas_datareader) (2.25.1)
# Requirement already satisfied: numpy>=1.16.5 in g:\python_1\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in g:\python_1\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in g:\python_1\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: six>=1.5 in g:\python_1\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in g:\python_1\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in g:\python_1\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in g:\python_1\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in g:\python_1\lib\site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0

# %%
import datetime
#from pandas_datareader import data,wb
from pandas_datareader import data,wb

# %%
#Get the data-
#we need to get the data using pandas datareader.
#we will get stock-information for the following banks.
#1.Bank of America
#2.citigroup
#3.Goldman sachs
#4.JPMorgan Chase
#5.Morgan Stanley
#6.Wells Forgo

# %%
#figure out how to get stock data from Jan 2006 to Jan 2016 for each of these banks.
#set each bank to be a seperate dataframe with the variable name for that bank being its ticker symbol.
#This will involve few steps .
#1.Use datetime to set start and end datetime objects.
#2.figure out the ticker symbol for each bank.
#3.figure out how to use datareader to grab the info on the stock.
import datetime
start=datetime.datetime(2006,1,1)
end=datetime.datetime(2016,1,1)

# %%
#Bank of America
BAC=data.DataReader("BAC","yahoo",start,end)
BAC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.942673
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.582169
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.625427
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.574963
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.596603
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.356147
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.231659
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.365035
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.160526
# 2015-12-31  17.070000  16.830000  17.010000  16.830000  47153000.0  14.964908
#
# [2517 rows x 6 columns]

# %%
BAC['Close'].max()
# Out:
# 54.900001525878906

# %%
#citigroup
C=data.DataReader("C","yahoo",start,end)
C
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2006-01-03  493.799988  481.100006  490.000000  492.899994   1537600.0
# 2006-01-04  491.000000  483.500000  488.600006  483.799988   1870960.0
# 2006-01-05  487.799988  484.000000  484.399994  486.200012   1143160.0
# 2006-01-06  489.000000  482.000000  488.799988  486.200012   1370210.0
# 2006-01-09  487.399994  483.000000  486.000000  483.899994   1680740.0
# ...                ...         ...         ...         ...         ...
# 2015-12-24   52.970001   52.450001   52.480000   52.709999   4671200.0
# 2015-12-28   52.570000   51.959999   52.570000   52.380001   8761700.0
# 2015-12-29   53.220001   52.740002   52.759998   52.980000  10155100.0
# 2015-12-30   52.939999   52.250000   52.840000   52.299999   8763300.0
# 2015-12-31   52.389999   51.750000   52.070000   51.750000  11281800.0
#
#              Adj Close
# Date
# 2006-01-03  368.265564
# 2006-01-04  361.466522
# 2006-01-05  363.259674
# 2006-01-06  363.259674
# 2006-01-09  361.541382
# ...                ...
# 2015-12-24   45.675972
# 2015-12-28   45.390015
# 2015-12-29   45.909939
# 2015-12-30   45.320686
# 2015-12-31   44.844097
#
# [2517 rows x 6 columns]

# %%
#Goldman Sachs
GS=data.DataReader("GS","yahoo",start,end)
GS
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  55.090000  54.709999  54.970001  54.820000   4999400.0  45.757153
# 2015-12-28  54.779999  54.169998  54.549999  54.680000   8288800.0  45.640301
# 2015-12-29  55.349998  54.990002  55.110001  55.290001   7894900.0  46.149448
# 2015-12-30  55.310001  54.790001  55.270000  54.889999   8016900.0  45.815578
# 2015-12-31  54.950001  54.220001  54.509998  54.360001  10929800.0  45.373203
#
# [2517 rows x 6 columns]

# %%
df=data.DataReader(['BAC','C','GS','JPM','MS','WFC'],'yahoo',start,end)
df.head()
# Out:
# Attributes  Adj Close                                                \
# Symbols           BAC           C          GS        JPM         MS
# Date
# 2006-01-03  33.942650  368.265564  103.863991  26.503397  36.114262
# 2006-01-04  33.582184  361.466461  102.429382  26.350418  36.139042
# 2006-01-05  33.625431  363.259766  102.389122  26.430243  36.238125
# 2006-01-06  33.574951  363.259766  103.839752  26.616463  36.275291
# 2006-01-09  33.596588  361.541229  105.088982  27.048763  36.659290
#
# Attributes                 Close                                     ...  \
# Symbols           WFC        BAC           C          GS        JPM  ...
# Date                                                                 ...
# 2006-01-03  20.444872  47.080002  492.899994  128.869995  40.189999  ...
# 2006-01-04  20.207741  46.580002  483.799988  127.089996  39.619999  ...
# 2006-01-05  20.185303  46.639999  486.200012  127.040001  39.740002  ...
# 2006-01-06  20.303877  46.570000  486.200012  128.839996  40.020000  ...
# 2006-01-09  20.300667  46.599998  483.899994  130.389999  40.669998  ...
#
# Attributes        Open                                       Volume  \
# Symbols             GS        JPM         MS        WFC         BAC
# Date
# 2006-01-03  126.699997  39.830002  57.169998  31.600000  16296700.0
# 2006-01-04  127.349998  39.779999  58.700001  31.799999  17757900.0
# 2006-01-05  126.000000  39.610001  58.549999  31.500000  14970700.0
# 2006-01-06  127.290001  39.919998  58.770000  31.580000  12599800.0
# 2006-01-09  128.500000  39.880001  58.630001  31.674999  15619400.0
#
# Attributes
# Symbols             C         GS         JPM         MS         WFC
# Date
# 2006-01-03  1537600.0  6188700.0  12838600.0  5377000.0  11016400.0
# 2006-01-04  1870960.0  4861600.0  13491500.0  7977800.0  10870000.0
# 2006-01-05  1143160.0  3717400.0   8109400.0  5778000.0  10158000.0
# 2006-01-06  1370210.0  4319600.0   7966900.0  6889800.0   8403800.0
# 2006-01-09  1680740.0  4723500.0  16575200.0  4144500.0   5619600.0
#
# [5 rows x 36 columns]

# %%
#create a list of ticker symbols in alphabetical order
tickers=['BAC','C','GS','JPM','MS','WFC']

# %%
#use pd.concat to concatenate the bank dataframes to a single dataframe called bank_stocks.set the keys argument equal to 
#the ticker list
import pandas as pd
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.942673
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.582169
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.625427
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.574963
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.596603
#
#                      C                                      ...         MS  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  57.169998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  58.700001
# 2006-01-05  487.799988  484.000000  484.399994  486.200012  ...  58.549999
# 2006-01-06  489.000000  482.000000  488.799988  486.200012  ...  58.770000
# 2006-01-09  487.399994  483.000000  486.000000  483.899994  ...  58.630001
#
#                                                    WFC                        \
#                 Close     Volume  Adj Close       High        Low       Open
# Date
# 2006-01-03  58.310001  5377000.0  36.114273  31.975000  31.195000  31.600000
# 2006-01-04  58.349998  7977800.0  36.139038  31.820000  31.365000  31.799999
# 2006-01-05  58.509998  5778000.0  36.238129  31.555000  31.309999  31.500000
# 2006-01-06  58.570000  6889800.0  36.275291  31.775000  31.385000  31.580000
# 2006-01-09  59.189999  4144500.0  36.659290  31.825001  31.555000  31.674999
#
#
#                 Close      Volume  Adj Close
# Date
# 2006-01-03  31.900000  11016400.0  20.444868
# 2006-01-04  31.530001  10870000.0  20.207739
# 2006-01-05  31.495001  10158000.0  20.185307
# 2006-01-06  31.680000   8403800.0  20.303873
# 2006-01-09  31.674999   5619600.0  20.300667
#
# [5 rows x 36 columns]

# %%
#set the column name levels
bank_stocks.columns.names=['Bank Tickers','Stock Info']

# %%
#what is the max close price for each banks stock throught the time period?
#cross section method
bank_stocks.xs(key='Close',level='Stock Info',axis=1).max()
# Out:
# Bank Tickers
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
#create a new empty dataframe .This dataframe will contain the returns for each banks stock.
returns=pd.DataFrame()
returns
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#we can use pct_change() method on close column to create a column representing this return value.
#create a for loop that goes and for each Bank Stock tickers creates this return column .
tickers=['BAC','C','GS','JPM','MS','WFC']
for tick in tickers:
    returns[tick + ' Return']=bank_stocks[tick]['Close'].pct_change()

# %%
returns[1:]
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158
# 2006-01-10   -0.008369  0.003100   0.012578    0.001475   0.000507   -0.000789
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# [2516 rows x 6 columns]

# %%
#create a pairplot using seaborn of returns dataframe
import seaborn as sns
sns.pairplot(returns[1:])

# %%
#MS Stock and citi group returns crashes as seen in fig.

# %%
#using this returns dataframe figure out on what dates each bank stock had the best and worst single day return?
#each banks max and min return value
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
#JPM have largest drop on 20-01-2009 and biggest gain on  the next day 21-01-2009

# %%
#take a look at std of the returns .which banks stock would you classify as the riskest over the entire reutime period
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
#riskest is citigroup

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
#for 2015 the stock of Morgan Stanley was risky

# %%
## distplot for 2015 return for Morgan Stanley
sns.set_style('whitegrid')
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'],color='green',bins=50)
# Out:
# G:\Python_1\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MS Return', ylabel='Density'>

# %%
#it deviate 0.06 from the average or mean value

# %%
#2008 return for all banks
returns.loc['2008-01-01':'2008-12-31'].std()
# Out:
# BAC Return    0.062934
# C Return      0.073523
# GS Return     0.050015
# JPM Return    0.053134
# MS Return     0.087604
# WFC Return    0.052439
# dtype: float64

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'],color='red',bins=50)
# Out:
# G:\Python_1\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='C Return', ylabel='Density'>

# %%
#create a line plot showing close price for each bank for the entire index of time.
import matplotlib.pyplot as plt
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick,figsize=(12,4))
plt.legend()

# %%
# !pip install cufflinks
